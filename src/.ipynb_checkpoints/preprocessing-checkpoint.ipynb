# %%
from pathlib import Path
import pandas as pd

# %%
file_path = 'data/deft_files/train/t1_biology_0_0.deft'

# %%
fp = Path(file_path)

# %%
text = fp.read_text().strip()

# %%
lines = text.split('\n\n')

# %%
data = []
for i,line in enumerate(lines):
    words = line.split('\n')
    for word in words:
        row = word.split('\t')
        row.append(i)
        data.append(row)

# %%
labels = ['TOKEN', 'TXT_SOURCE_FILE', 'START_CHAR', 'END_CHAR' ,'TAG', 'TAG_ID', 'ROOT_ID', 'RELATION','SENT']
df = pd.DataFrame(data,columns=labels)

# %%
df[0:60]
# Out:
#           TOKEN                       TXT_SOURCE_FILE START_CHAR END_CHAR  \
# 0             5   data/source_txt/t1_biology_0_0.deft        250      251
# 1             .   data/source_txt/t1_biology_0_0.deft        251      252
# 2       Science   data/source_txt/t1_biology_0_0.deft        253      260
# 3      includes   data/source_txt/t1_biology_0_0.deft        261      269
# 4          such   data/source_txt/t1_biology_0_0.deft        270      274
# 5       diverse   data/source_txt/t1_biology_0_0.deft        275      282
# 6        fields   data/source_txt/t1_biology_0_0.deft        283      289
# 7            as   data/source_txt/t1_biology_0_0.deft        290      292
# 8     astronomy   data/source_txt/t1_biology_0_0.deft        293      302
# 9             ,   data/source_txt/t1_biology_0_0.deft        302      303
# 10      biology   data/source_txt/t1_biology_0_0.deft        304      311
# 11            ,   data/source_txt/t1_biology_0_0.deft        311      312
# 12     computer   data/source_txt/t1_biology_0_0.deft        313      321
# 13     sciences   data/source_txt/t1_biology_0_0.deft        322      330
# 14            ,   data/source_txt/t1_biology_0_0.deft        330      331
# 15      geology   data/source_txt/t1_biology_0_0.deft        332      339
# 16            ,   data/source_txt/t1_biology_0_0.deft        339      340
# 17        logic   data/source_txt/t1_biology_0_0.deft        341      346
# 18            ,   data/source_txt/t1_biology_0_0.deft        346      347
# 19      physics   data/source_txt/t1_biology_0_0.deft        348      355
# 20            ,   data/source_txt/t1_biology_0_0.deft        355      356
# 21    chemistry   data/source_txt/t1_biology_0_0.deft        357      366
# 22            ,   data/source_txt/t1_biology_0_0.deft        366      367
# 23          and   data/source_txt/t1_biology_0_0.deft        368      371
# 24  mathematics   data/source_txt/t1_biology_0_0.deft        372      383
# 25            (   data/source_txt/t1_biology_0_0.deft        384      385
# 26            [   data/source_txt/t1_biology_0_0.deft        385      386
# 27         link   data/source_txt/t1_biology_0_0.deft        386      390
# 28            ]   data/source_txt/t1_biology_0_0.deft        390      391
# 29            )   data/source_txt/t1_biology_0_0.deft        391      392
# 30            .   data/source_txt/t1_biology_0_0.deft        392      393
# 31      However   data/source_txt/t1_biology_0_0.deft        402      409
# 32            ,   data/source_txt/t1_biology_0_0.deft        409      410
# 33        those   data/source_txt/t1_biology_0_0.deft        411      416
# 34       fields   data/source_txt/t1_biology_0_0.deft        417      423
# 35           of   data/source_txt/t1_biology_0_0.deft        424      426
# 36      science   data/source_txt/t1_biology_0_0.deft        427      434
# 37      related   data/source_txt/t1_biology_0_0.deft        435      442
# 38           to   data/source_txt/t1_biology_0_0.deft        443      445
# 39          the   data/source_txt/t1_biology_0_0.deft        446      449
# 40     physical   data/source_txt/t1_biology_0_0.deft        450      458
# 41        world   data/source_txt/t1_biology_0_0.deft        459      464
# 42          and   data/source_txt/t1_biology_0_0.deft        465      468
# 43          its   data/source_txt/t1_biology_0_0.deft        469      472
# 44    phenomena   data/source_txt/t1_biology_0_0.deft        473      482
# 45          and   data/source_txt/t1_biology_0_0.deft        483      486
# 46    processes   data/source_txt/t1_biology_0_0.deft        487      496
# 47          are   data/source_txt/t1_biology_0_0.deft        497      500
# 48   considered   data/source_txt/t1_biology_0_0.deft        501      511
# 49      natural   data/source_txt/t1_biology_0_0.deft        512      519
# 50     sciences   data/source_txt/t1_biology_0_0.deft        520      528
# 51            .   data/source_txt/t1_biology_0_0.deft        528      529
# 52         Thus   data/source_txt/t1_biology_0_0.deft        536      540
# 53            ,   data/source_txt/t1_biology_0_0.deft        540      541
# 54            a   data/source_txt/t1_biology_0_0.deft        542      543
# 55       museum   data/source_txt/t1_biology_0_0.deft        544      550
# 56           of   data/source_txt/t1_biology_0_0.deft        551      553
# 57      natural   data/source_txt/t1_biology_0_0.deft        554      561
# 58     sciences   data/source_txt/t1_biology_0_0.deft        562      570
# 59        might   data/source_txt/t1_biology_0_0.deft        571      576
#
#               TAG TAG_ID ROOT_ID         RELATION  SENT
# 0               O     -1      -1                0   0.0
# 1               O     -1      -1                0   0.0
# 2               O     -1      -1                0   1.0
# 3               O     -1      -1                0   1.0
# 4               O     -1      -1                0   1.0
# 5               O     -1      -1                0   1.0
# 6               O     -1      -1                0   1.0
# 7               O     -1      -1                0   1.0
# 8               O     -1      -1                0   1.0
# 9               O     -1      -1                0   1.0
# 10              O     -1      -1                0   1.0
# 11              O     -1      -1                0   1.0
# 12              O     -1      -1                0   1.0
# 13              O     -1      -1                0   1.0
# 14              O     -1      -1                0   1.0
# 15              O     -1      -1                0   1.0
# 16              O     -1      -1                0   1.0
# 17              O     -1      -1                0   1.0
# 18              O     -1      -1                0   1.0
# 19              O     -1      -1                0   1.0
# 20              O     -1      -1                0   1.0
# 21              O     -1      -1                0   1.0
# 22              O     -1      -1                0   1.0
# 23              O     -1      -1                0   1.0
# 24              O     -1      -1                0   1.0
# 25              O     -1      -1                0   1.0
# 26              O     -1      -1                0   1.0
# 27              O     -1      -1                0   1.0
# 28              O     -1      -1                0   1.0
# 29              O     -1      -1                0   1.0
# 30              O     -1      -1                0   1.0
# 31              O     -1      -1                0   2.0
# 32              O     -1      -1                0   2.0
# 33   B-Definition   T127    T128   Direct-Defines   2.0
# 34   I-Definition   T127    T128   Direct-Defines   2.0
# 35   I-Definition   T127    T128   Direct-Defines   2.0
# 36   I-Definition   T127    T128   Direct-Defines   2.0
# 37   I-Definition   T127    T128   Direct-Defines   2.0
# 38   I-Definition   T127    T128   Direct-Defines   2.0
# 39   I-Definition   T127    T128   Direct-Defines   2.0
# 40   I-Definition   T127    T128   Direct-Defines   2.0
# 41   I-Definition   T127    T128   Direct-Defines   2.0
# 42   I-Definition   T127    T128   Direct-Defines   2.0
# 43   I-Definition   T127    T128   Direct-Defines   2.0
# 44   I-Definition   T127    T128   Direct-Defines   2.0
# 45   I-Definition   T127    T128   Direct-Defines   2.0
# 46   I-Definition   T127    T128   Direct-Defines   2.0
# 47              O     -1      -1                0   2.0
# 48              O     -1      -1                0   2.0
# 49         B-Term   T128       0                0   2.0
# 50         I-Term   T128       0                0   2.0
# 51              O     -1      -1                0   2.0
# 52              O     -1      -1                0   3.0
# 53              O     -1      -1                0   3.0
# 54              O     -1      -1                0   3.0
# 55              O     -1      -1                0   3.0
# 56              O     -1      -1                0   3.0
# 57              O     -1      -1                0   3.0
# 58              O     -1      -1                0   3.0
# 59              O     -1      -1                0   3.0
